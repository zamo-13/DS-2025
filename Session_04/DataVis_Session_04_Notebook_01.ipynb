# %% [markdown]
# # Data Vis: Data Maps
# * Notebook 1: Drawing Maps and Plotting Data on Them

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import folium

# %% [markdown]
# ## Drawing an Empty Map

# %% [markdown]
# We will start by drawing an empty map of Berlin. We will use the `Folium` library to do this. Folium is a Python library that makes it easy to visualize data that’s been manipulated in Python on an interactive map. It is built on the Leaflet JavaScript library, which is one of the most popular libraries for interactive maps.
#
# To draw a map, we need to specify the location and zoom level. The location is specified by latitude and longitude coordinates, and the zoom level is an integer that specifies how far we want to zoom in on the map. A zoom level of 10 means we are zoomed out to see a large area, while a zoom level of 20 means we are zoomed in to see a small area.
#
# ```bash

# %%
m = folium.Map(
    location=(52.51626496858416, 13.377444487395968),
    zoom_start=20)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1392760011b779fd43630977023ee3e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1392760011b779fd43630977023ee3e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1392760011b779fd43630977023ee3e9 = L.map(
#                 &quot;map_1392760011b779fd43630977023ee3e9&quot;,
#                 {
#                     center: [52.51626496858416, 13.377444487395968],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 20,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bc89d1b002e5685e557ac44a2474b03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3bc89d1b002e5685e557ac44a2474b03.addTo(map_1392760011b779fd43630977023ee3e9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Changing the Map Tiles

# %% [markdown]
# By default, Folium uses OpenStreetMap tiles to draw the map. However, we can change the map tiles to use different tile providers. Folium supports several tile providers, including Stamen and Mapbox, out of the box. But we can also use all tile providers supported by Leaflet. You can find a list of all tile providers [here](https://leaflet-extras.github.io/leaflet-providers/preview/).

# %%
m = folium.Map(
    location=(52.51626496858416, 13.377448787395968),
    zoom_start=15,
    tiles='https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png',
    attr='OpenTopoMap'
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd6f63c0ceed0f50d2116ff4f94ca191 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd6f63c0ceed0f50d2116ff4f94ca191&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd6f63c0ceed0f50d2116ff4f94ca191 = L.map(
#                 &quot;map_bd6f63c0ceed0f50d2116ff4f94ca191&quot;,
#                 {
#                     center: [52.51626496858416, 13.377448787395968],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_289a74b47183f950dcb0eb3c62dc18e2 = L.tileLayer(
#                 &quot;https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenTopoMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_289a74b47183f950dcb0eb3c62dc18e2.addTo(map_bd6f63c0ceed0f50d2116ff4f94ca191);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Plotting Points on the Map

# %% [markdown]
# Let's start to actually draw on the map by providing some data. We will begin by adding points, defined by their latitude and longitude coordinates. Markers can be enriched with icons, popups, tooltips and other information. We simply create a `Marker` object and then add it to the map.

# %%
m = folium.Map(
    location=(52.518361185274614, 13.359599085472585),
    zoom_start=14,
    attr='OpenTopoMap'
)

folium.Marker(
    location=[52.51626496858416, 13.377448787395968],
    popup="Brandenburger Tor",
    icon=folium.Icon(color="red"),
).add_to(m)

folium.Marker(
    location=[52.51461940212162, 13.350239325281784],
    popup="Siegessäule",
    icon=folium.Icon(color="red"),
).add_to(m)

folium.Marker(
    location=[52.52415952449152, 13.370092571212059],
    popup="HBF",
    icon=folium.Icon(color="blue"),
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b81d77980833283253b46cf4659387f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b81d77980833283253b46cf4659387f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b81d77980833283253b46cf4659387f = L.map(
#                 &quot;map_7b81d77980833283253b46cf4659387f&quot;,
#                 {
#                     center: [52.518361185274614, 13.359599085472585],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2688bbe15084e39e0b1380a0c3b2485 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenTopoMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2688bbe15084e39e0b1380a0c3b2485.addTo(map_7b81d77980833283253b46cf4659387f);
#
#
#             var marker_d82b748d04150543391a833066453c33 = L.marker(
#                 [52.51626496858416, 13.377448787395968],
#                 {
# }
#             ).addTo(map_7b81d77980833283253b46cf4659387f);
#
#
#             var icon_c9737d58dba8d858db07f148f2104fd6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e33fc6933fe6c03da612ae490a91d26d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_945554ff8cda1acb78139ca2ef599995 = $(`&lt;div id=&quot;html_945554ff8cda1acb78139ca2ef599995&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brandenburger Tor&lt;/div&gt;`)[0];
#                 popup_e33fc6933fe6c03da612ae490a91d26d.setContent(html_945554ff8cda1acb78139ca2ef599995);
#
#
#
#         marker_d82b748d04150543391a833066453c33.bindPopup(popup_e33fc6933fe6c03da612ae490a91d26d)
#         ;
#
#
#
#
#                 marker_d82b748d04150543391a833066453c33.setIcon(icon_c9737d58dba8d858db07f148f2104fd6);
#
#
#             var marker_d3916568440c396e25065c97c3b05234 = L.marker(
#                 [52.51461940212162, 13.350239325281784],
#                 {
# }
#             ).addTo(map_7b81d77980833283253b46cf4659387f);
#
#
#             var icon_a607278c35e240eb2760675cd8b5a3da = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b5d6d5894338f9e364f465ad01c0d202 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be4fc909283ed43e6ad16340e0c89e5e = $(`&lt;div id=&quot;html_be4fc909283ed43e6ad16340e0c89e5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Siegessäule&lt;/div&gt;`)[0];
#                 popup_b5d6d5894338f9e364f465ad01c0d202.setContent(html_be4fc909283ed43e6ad16340e0c89e5e);
#
#
#
#         marker_d3916568440c396e25065c97c3b05234.bindPopup(popup_b5d6d5894338f9e364f465ad01c0d202)
#         ;
#
#
#
#
#                 marker_d3916568440c396e25065c97c3b05234.setIcon(icon_a607278c35e240eb2760675cd8b5a3da);
#
#
#             var marker_4e6451f77e8ea5a2a5cd062e83542a21 = L.marker(
#                 [52.52415952449152, 13.370092571212059],
#                 {
# }
#             ).addTo(map_7b81d77980833283253b46cf4659387f);
#
#
#             var icon_3532d4ec0941056dbc620ab3cb04c3f4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a713aaa4960f9411d8f0a7c2a4272186 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd25f701de15dcd1f52a8c271fd8c329 = $(`&lt;div id=&quot;html_fd25f701de15dcd1f52a8c271fd8c329&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;HBF&lt;/div&gt;`)[0];
#                 popup_a713aaa4960f9411d8f0a7c2a4272186.setContent(html_fd25f701de15dcd1f52a8c271fd8c329);
#
#
#
#         marker_4e6451f77e8ea5a2a5cd062e83542a21.bindPopup(popup_a713aaa4960f9411d8f0a7c2a4272186)
#         ;
#
#
#
#
#                 marker_4e6451f77e8ea5a2a5cd062e83542a21.setIcon(icon_3532d4ec0941056dbc620ab3cb04c3f4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none

# %% [markdown]
# ## Plotting Lines on the Map

# %% [markdown]
# Similarily, we can plot lines on the map. We will use the `PolyLine` class to do this. A polyline is a series of connected line segments. We can specify the color, weight and opacity of the line. We can also add popups and tooltips to the line.

# %%
line1_segments = [(52.51626496858416, 13.377448787395968),
                  (52.51461940212162, 13.350239325281784)]

line2_segments = [(52.52415952449152, 13.370092571212059),
                  (52.51461940212162, 13.350239325281784)]

line3_segments = [(52.52415952449152, 13.370092571212059),
                  (52.51626496858416, 13.377448787395968)]

folium.PolyLine(line1_segments, color="blue").add_to(m)
folium.PolyLine(line2_segments, color="blue").add_to(m)
folium.PolyLine(line3_segments, color="blue").add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b81d77980833283253b46cf4659387f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b81d77980833283253b46cf4659387f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b81d77980833283253b46cf4659387f = L.map(
#                 &quot;map_7b81d77980833283253b46cf4659387f&quot;,
#                 {
#                     center: [52.518361185274614, 13.359599085472585],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2688bbe15084e39e0b1380a0c3b2485 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;OpenTopoMap&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2688bbe15084e39e0b1380a0c3b2485.addTo(map_7b81d77980833283253b46cf4659387f);
#
#
#             var marker_d82b748d04150543391a833066453c33 = L.marker(
#                 [52.51626496858416, 13.377448787395968],
#                 {
# }
#             ).addTo(map_7b81d77980833283253b46cf4659387f);
#
#
#             var icon_c9737d58dba8d858db07f148f2104fd6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e33fc6933fe6c03da612ae490a91d26d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_945554ff8cda1acb78139ca2ef599995 = $(`&lt;div id=&quot;html_945554ff8cda1acb78139ca2ef599995&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brandenburger Tor&lt;/div&gt;`)[0];
#                 popup_e33fc6933fe6c03da612ae490a91d26d.setContent(html_945554ff8cda1acb78139ca2ef599995);
#
#
#
#         marker_d82b748d04150543391a833066453c33.bindPopup(popup_e33fc6933fe6c03da612ae490a91d26d)
#         ;
#
#
#
#
#                 marker_d82b748d04150543391a833066453c33.setIcon(icon_c9737d58dba8d858db07f148f2104fd6);
#
#
#             var marker_d3916568440c396e25065c97c3b05234 = L.marker(
#                 [52.51461940212162, 13.350239325281784],
#                 {
# }
#             ).addTo(map_7b81d77980833283253b46cf4659387f);
#
#
#             var icon_a607278c35e240eb2760675cd8b5a3da = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b5d6d5894338f9e364f465ad01c0d202 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be4fc909283ed43e6ad16340e0c89e5e = $(`&lt;div id=&quot;html_be4fc909283ed43e6ad16340e0c89e5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Siegessäule&lt;/div&gt;`)[0];
#                 popup_b5d6d5894338f9e364f465ad01c0d202.setContent(html_be4fc909283ed43e6ad16340e0c89e5e);
#
#
#
#         marker_d3916568440c396e25065c97c3b05234.bindPopup(popup_b5d6d5894338f9e364f465ad01c0d202)
#         ;
#
#
#
#
#                 marker_d3916568440c396e25065c97c3b05234.setIcon(icon_a607278c35e240eb2760675cd8b5a3da);
#
#
#             var marker_4e6451f77e8ea5a2a5cd062e83542a21 = L.marker(
#                 [52.52415952449152, 13.370092571212059],
#                 {
# }
#             ).addTo(map_7b81d77980833283253b46cf4659387f);
#
#
#             var icon_3532d4ec0941056dbc620ab3cb04c3f4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a713aaa4960f9411d8f0a7c2a4272186 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd25f701de15dcd1f52a8c271fd8c329 = $(`&lt;div id=&quot;html_fd25f701de15dcd1f52a8c271fd8c329&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;HBF&lt;/div&gt;`)[0];
#                 popup_a713aaa4960f9411d8f0a7c2a4272186.setContent(html_fd25f701de15dcd1f52a8c271fd8c329);
#
#
#
#         marker_4e6451f77e8ea5a2a5cd062e83542a21.bindPopup(popup_a713aaa4960f9411d8f0a7c2a4272186)
#         ;
#
#
#
#
#                 marker_4e6451f77e8ea5a2a5cd062e83542a21.setIcon(icon_3532d4ec0941056dbc620ab3cb04c3f4);
#
#
#             tile_layer_c2688bbe15084e39e0b1380a0c3b2485.addTo(map_7b81d77980833283253b46cf4659387f

# %% [markdown]
# ## Your Turn

# %% [markdown]
# Now it is your turn to play around with maps in Folium (https://python-visualization.github.io/folium/).
#
# Concreteley, you can try to:
# 1) Draw an empty map of your hometown or any other city (e.g., New York City)
# 2) Change the map tiles to use a different tile provider
# 3) Add markers of different types to the map (e.g., points of interest, public transport, restaurants, your home, etc.)
# 4) Connect the markers with lines

# %%
import folium as f

# %%
lmo = f.Map(
    location=(52.51626496858416, 13.377448787395968),
    zoom_start=10
)
lmo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed719e30d565779e1b61f5d48be0af73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed719e30d565779e1b61f5d48be0af73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed719e30d565779e1b61f5d48be0af73 = L.map(
#                 &quot;map_ed719e30d565779e1b61f5d48be0af73&quot;,
#                 {
#                     center: [52.51626496858416, 13.377448787395968],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a827b1e9ee31e09f027f7893d8a0e921 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a827b1e9ee31e09f027f7893d8a0e921.addTo(map_ed719e30d565779e1b61f5d48be0af73);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
